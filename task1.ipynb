# %%
import requests
import pandas as pd
api_url = "https://api.binance.com/api/v3/ticker/24hr"
response = requests.get(api_url)
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    display(df.head())
    df.to_csv("binance_data.csv", index=False)
    print("CSV file created successfully.")
else:
    print(f"Error: {response.status_code}")
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  -0.00107000             -1.924       0.05496219     0.05563000
# 1   LTCBTC  -0.00003000             -1.376       0.00214828     0.00218000
# 2   BNBBTC  -0.00009100             -1.214       0.00743123     0.00749500
# 3   NEOBTC  -0.00000700             -2.894       0.00023836     0.00024180
# 4  QTUMETH  -0.00001500             -1.085       0.00137497     0.00138400
#
#     lastPrice     lastQty    bidPrice        bidQty    askPrice  ...  \
# 0  0.05455000  9.27380000  0.05455000   58.08540000  0.05456000  ...
# 1  0.00215000  4.50300000  0.00215000  138.61600000  0.00215100  ...
# 2  0.00740400  0.62500000  0.00740300    8.96100000  0.00740400  ...
# 3  0.00023490  3.47000000  0.00023490   15.94000000  0.00023510  ...
# 4  0.00136800  5.30000000  0.00136100  202.40000000  0.00136800  ...
#
#     openPrice   highPrice    lowPrice          volume    quoteVolume  \
# 0  0.05562000  0.05574000  0.05445000  24489.50550000  1345.99675153
# 1  0.00218000  0.00218200  0.00212000  28056.68200000    60.27363836
# 2  0.00749500  0.00751200  0.00737500  17647.40800000   131.14192407
# 3  0.00024190  0.00024190  0.00023490   7601.98000000     1.81201662
# 4  0.00138300  0.00139100  0.00136800    167.40000000     0.23017040
#
#         openTime      closeTime    firstId     lastId  count
# 0  1697635142267  1697721542267  424055542  424081808  26267
# 1  1697635142606  1697721542606   93814002   93822079   8078
# 2  1697635142778  1697721542778  227869525  227891601  22077
# 3  1697635141188  1697721541188   45561388   45562228    841
# 4  1697635094041  1697721494041    5404026    5404040     15
#
# [5 rows x 21 columns]
# CSV file created successfully.
